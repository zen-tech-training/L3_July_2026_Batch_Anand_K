# %%
from langchain_ollama import ChatOllama

# Built-in tool provided by langchain
from langchain_community.tools import DuckDuckGoSearchResults
import langchain
langchain.__version__
from langchain.agents import create_agent
from langchain.tools import tool

model = ChatOllama(model="gpt-oss:120b-cloud")

# %%
search_tool = DuckDuckGoSearchResults()
response = search_tool.invoke("News about CJP students protest in New Delhi")
print(response)
# Out:
# snippet: 19 hours ago ... In India, tens of thousands of Gen Z protesters have taken to the streets of the capital Delhi, calling for the resignation of the country's education minister., title: Jantar Mantar: What is the Gen Z CJP protest in Delhi about? - BBC, link: https://www.bbc.com/news/articles/cedj9j911p8o, snippet: 18 hours ago ... Delhi Protest Escalates Thousands of Cockroach Janta Party (CJP) supporters marched towards Parliament in New Delhi today, demanding action over repeated exam ..., title: Thousands marched on parliament in Delhi despite a police ban, in ..., link: https://www.instagram.com/p/DbDY3Jimp2G/, snippet: 18 hours ago ... The heart of New Delhi – Parliament Street and Connaught Place, a colonial-era square – bears the imprint of Monday's police crackdown on thousands of ..., title: 'Won't back down': Indian student protesters return after police ..., link: https://www.aljazeera.com/news/2026/7/21/wont-back-down-indian-student-protesters-return-after-police-crackdown, snippet: 14 hours ago ... Supporters of the Cockroach Janta Party (CJP) gathered at Jantar Mantar in New Delhi, demanding accountability over alleged examination irregularities and ..., title: CJP protesters gather at Jantar Mantar in New Delhi - YouTube, link: https://www.youtube.com/watch?v=EALpZUMRJvk
